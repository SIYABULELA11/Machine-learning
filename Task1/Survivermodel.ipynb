# %% [markdown]
# # Model that predicts the survivers of titanic

# %% [markdown]
# ## Data exploration

# %% [markdown]
# #### **loading Datasets**

# %%
import pandas as pd
df_train=pd.read_csv('./train.csv')
df_test= pd.read_csv('./test.csv')

df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Data cleaning and preprocessing

# %% [markdown]
# #### Plan

# %% [markdown]
# To use df_test for testing the model after training it with df_train dataframe

# %% [markdown]
# #### Dropping the non useful columns

# %%
df_train.drop(['PassengerId', 'Name', 'Ticket', 'Cabin','Fare'], axis=1, inplace=True)

df_test.drop(['PassengerId', 'Name', 'Ticket', 'Cabin','Fare'], axis=1, inplace=True)
df_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch Embarked
# 0         3    male  34.5      0      0        Q
# 1         3  female  47.0      1      0        S
# 2         2    male  62.0      0      0        Q
# 3         3    male  27.0      0      0        S
# 4         3  female  22.0      1      1        S
# ..      ...     ...   ...    ...    ...      ...
# 413       3    male   NaN      0      0        S
# 414       1  female  39.0      0      0        C
# 415       3    male  38.5      0      0        S
# 416       3    male   NaN      0      0        S
# 417       3    male   NaN      1      1        C
#
# [418 rows x 6 columns]

# %% [markdown]
# #### Handling missing values

# %% [markdown]
# **for df_train**

# %%
empty_count = df_train['Embarked'].isnull().sum()
if empty_count>0:
    df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace=True)

empty_count2 =df_train['Sex'].isnull().sum()
if empty_count2>0:
    df_train['Sex'].fillna(df_train['Sex'].mode()[0], inplace=True)

empty_count3 =df_train['Age'].isnull().sum()
if empty_count3>0:
    df_train['Age'].fillna(df_train['Age'].median(), inplace=True)

empty_count4 =df_train['Parch'].isnull().sum()
if empty_count4>0:
    df_train['Parch'].fillna(df_train['Parch'].mode()[0], inplace=True)

empty_count5 =df_train['SibSp'].isnull().sum()
if empty_count5>0:
    df_train['SibSp'].fillna(df_train['SibSp'].mode()[0], inplace=True)

empty_count6 =df_train['Pclass'].isnull().sum()
if empty_count6>0:
    df_train['Pclass'].fillna(df_train['Pclass'].mode()[0], inplace=True)

print(df_train.isnull().sum())
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Embarked    0
# dtype: int64
# C:\Users\siyam\AppData\Local\Temp\ipykernel_10088\3892687768.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace=True)
# C:\Users\siyam\AppData\Local\Temp\ipykernel_10088\3892687768.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# **for df_test**

# %%
empty_count = df_test['Embarked'].isnull().sum()
if empty_count>0:
    df_test['Embarked'].fillna(df_test['Embarked'].mode()[0], inplace=True)

empty_count2 =df_test['Sex'].isnull().sum()
if empty_count2>0:
    df_test['Sex'].fillna(df_test['Sex'].mode()[0], inplace=True)

empty_count3 =df_test['Age'].isnull().sum()
if empty_count3>0:
    df_test['Age'].fillna(df_test['Age'].median(), inplace=True)

empty_count4 =df_test['Parch'].isnull().sum()
if empty_count4>0:
    df_test['Parch'].fillna(df_test['Parch'].mode()[0], inplace=True)

empty_count5 =df_test['SibSp'].isnull().sum()
if empty_count5>0:
    df_test['SibSp'].fillna(df_test['SibSp'].mode()[0], inplace=True)

empty_count6 =df_test['Pclass'].isnull().sum()
if empty_count6>0:
    df_test['Pclass'].fillna(df_test['Pclass'].mode()[0], inplace=True)

print(df_test.isnull().sum())
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Embarked    0
# dtype: int64
# C:\Users\siyam\AppData\Local\Temp\ipykernel_10088\1607656222.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Age'].fillna(df_test['Age'].median(), inplace=True)

# %% [markdown]
# #### one-hot encoding for categorical variables

# %%
df_train = pd.get_dummies(df_train, columns=['Sex', 'Embarked'], dtype = int)
df_train
# Out:
#      Survived  Pclass   Age  SibSp  Parch  Sex_female  Sex_male  Embarked_C  \
# 0           0       3  22.0      1      0           0         1           0
# 1           1       1  38.0      1      0           1         0           1
# 2           1       3  26.0      0      0           1         0           0
# 3           1       1  35.0      1      0           1         0           0
# 4           0       3  35.0      0      0           0         1           0
# ..        ...     ...   ...    ...    ...         ...       ...         ...
# 886         0       2  27.0      0      0           0         1           0
# 887         1       1  19.0      0      0           1         0           0
# 888         0       3  28.0      1      2           1         0           0
# 889         1       1  26.0      0      0           0         1           1
# 890         0       3  32.0      0      0           0         1           0
#
#      Embarked_Q  Embarked_S
# ...

# %%
df_test = pd.get_dummies(df_test, columns=['Sex', 'Embarked'], dtype = int)
df_test
# Out:
#      Pclass   Age  SibSp  Parch  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0         3  34.5      0      0           0         1           0           1
# 1         3  47.0      1      0           1         0           0           0
# 2         2  62.0      0      0           0         1           0           1
# 3         3  27.0      0      0           0         1           0           0
# 4         3  22.0      1      1           1         0           0           0
# ..      ...   ...    ...    ...         ...       ...         ...         ...
# 413       3  27.0      0      0           0         1           0           0
# 414       1  39.0      0      0           1         0           1           0
# 415       3  38.5      0      0           0         1           0           0
# 416       3  27.0      0      0           0         1           0           0
# 417       3  27.0      1      1           0         1           1           0
#
#      Embarked_S
# ...

# %% [markdown]
# #### Separation of data as X and Y

# %% [markdown]
# **for df_train**

# %%
X_train= df_train.drop('Survived', axis=1)
Y_train = df_train['Survived']

# %% [markdown]
# **for df_test**

# %%
X_test = df_test
df_survival = pd.read_csv('./gender_submission.csv')
Y_test = df_survival.drop('PassengerId', axis=1)
Y_test
# Out:
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         0
# 417         0
#
# [418 rows x 1 columns]

# %% [markdown]
# ## Model building

# %% [markdown]
# **Random forest**

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_train, Y_train)

y_pred_rf = model_rf.predict(X_test)

# %% [markdown]
# **logistic regression**

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(max_iter=1000)
model_lr.fit(X_train, Y_train)
y_pred_lr = model_lr.predict(X_test)

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# **Random forest**

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(Y_test, y_pred_rf)
print(f"Validation Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(Y_test, y_pred_rf))
# Out:
# Validation Accuracy: 0.7368421052631579
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.70      0.77       266
#            1       0.60      0.80      0.69       152
#
#     accuracy                           0.74       418
#    macro avg       0.73      0.75      0.73       418
# weighted avg       0.77      0.74      0.74       418

# %% [markdown]
# **Logistic regression**

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(Y_test, y_pred_lr)
print(f"Validation Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(Y_test, y_pred_lr))
# Out:
# Validation Accuracy: 0.930622009569378
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       266
#            1       0.88      0.94      0.91       152
#
#     accuracy                           0.93       418
#    macro avg       0.92      0.93      0.93       418
# weighted avg       0.93      0.93      0.93       418

# %% [markdown]
# **CHOSEN MODEL: LOGISTIC REGRESSION MODEL**

# %% [markdown]
# ## Model Tuning

# %% [markdown]
# **Hyperparameter Tuning with Grid Search**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression


parameter_grid = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'max_iter': [100, 200, 300]
}

model = LogisticRegression(random_state=42, max_iter=1000)

grid_search = GridSearchCV(estimator=model, param_grid=parameter_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, Y_train)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Best parameters: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# Best cross-validation score: 0.7957190383528969
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 975 fits failed out of a total of 1500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 75 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# **Hyperparameter Tuning with Random Search**

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

parameter_dist = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'max_iter': randint(100, 1000)
}

model = LogisticRegression(random_state=42, max_iter=1000)
random_search = RandomizedSearchCV(estimator=model, param_distributions=parameter_dist, n_iter=100, cv=5, n_jobs=-1, verbose=2, random_state=42)
random_search.fit(X_train, Y_train)



print("Best parameters:", random_search.best_params_)
print("Best cross-validation score:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best parameters: {'C': 0.1, 'max_iter': 805, 'penalty': 'l2', 'solver': 'liblinear'}
# Best cross-validation score: 0.7957190383528969
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 360 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...
